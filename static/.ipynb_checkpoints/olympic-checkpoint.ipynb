# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('olympic.csv')
df
# Out:
#            City  Year      Sport       Discipline           Event  \
# 0      Montreal  1976   Aquatics           Diving  3m springboard
# 1      Montreal  1976   Aquatics           Diving  3m springboard
# 2      Montreal  1976   Aquatics           Diving  3m springboard
# 3      Montreal  1976   Aquatics           Diving  3m springboard
# 4      Montreal  1976   Aquatics           Diving    10m platform
# ...         ...   ...        ...              ...             ...
# 15311   Beijing  2008  Wrestling  Wrestling Gre-R       66 - 74kg
# 15312   Beijing  2008  Wrestling  Wrestling Gre-R       66 - 74kg
# 15313   Beijing  2008  Wrestling  Wrestling Gre-R       55 - 60kg
# 15314   Beijing  2008  Wrestling  Wrestling Gre-R       60 - 66kg
# 15315   Beijing  2008  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               K�HLER, Christa  Women          GDR   East Germany
# 1           KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 2          BOGGS, Philip George    Men          USA  United States
# 3      CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 4        WILSON, Deborah Keplar  Women          USA  United States
# ...                         ...    ...          ...            ...
# 15311        GUENOT, Christophe    Men          FRA         France
# 15312       KVIRKELIA, Manuchar    Men          GEO        Georgia
# 15313          RAHIMOV, Vitaliy    Men          AZE     Azerbaijan
# 15314            GUENOT, Steeve    Men          FRA         France
# 15315             LOPEZ, Mijain    Men          CUB           Cuba
#
#       Event_gender   Medal
# 0                W  Silver
# 1                M  Bronze
# 2                M    Gold
# 3                M  Silver
# 4                W  Bronze
# ...            ...     ...
# 15311            M  Bronze
# 15312            M    Gold
# 15313            M  Silver
# 15314            M    Gold
# 15315            M    Gold
#
# [15316 rows x 11 columns]

# %%
df['Country_Code'].unique()
# Out:
# array(['GDR', 'URS', 'USA', 'ITA', 'SWE', 'AUS', 'CAN', 'FRG', 'NED',
#        'GBR', 'HUN', 'JPN', 'CUB', 'POL', 'BUL', 'NZL', 'BEL', 'MEX',
#        'JAM', 'FIN', 'ROU', 'POR', 'FRA', 'BRA', 'TCH', 'TRI', 'YUG',
#        'VEN', 'PUR', 'PRK', 'BER', 'THA', 'ESP', 'DEN', 'SUI', 'PAK',
#        'KOR', 'NOR', 'AUT', 'IRI', 'MGL', 'ETH', 'TAN', 'GUY', 'UGA',
#        'IRL', 'IND', 'ZIM', 'GRE', 'LIB', 'CHN', 'NGR', 'KEN', 'MAR',
#        'CIV', 'ALG', 'TUR', 'CMR', 'ZAM', 'DOM', 'ISL', 'EGY', 'COL',
#        'PER', 'TPE', 'SYR', 'CRC', 'SUR', 'INA', 'DJI', 'SEN', 'PHI',
#        'AHO', 'ISV', 'CHI', 'ARG', 'EUN', 'GER', 'BAH', 'RSA', 'NAM',
#        'QAT', 'LTU', 'MAS', 'CRO', 'LAT', 'EST', 'GHA', 'ISR', 'SLO',
#        'IOP', 'RUS', 'UKR', 'BLR', 'BDI', 'ECU', 'MOZ', 'CZE', 'TUN',
#        'KAZ', 'TGA', 'UZB', 'SVK', 'MDA', 'GEO', 'HKG', 'ARM', 'AZE',
#        'KSA', 'BAR', 'SRI', 'URU', 'KGZ', 'KUW', 'VIE', 'MKD', 'SCG',
#        'ERI', 'PAR', 'UAE', 'SRB', 'PAN', 'SUD', 'MRI', 'TOG', 'TJK',
#        'SIN', 'AFG'], dtype=object)

# %%
df[df['Country_Code'] == 'RUS'].groupby('City').count()
# Out:
#          Year  Sport  Discipline  Event  Athlete  Gender  Country_Code  \
# City
# Athens    192    192         192    192      192     192           192
# Atlanta   115    115         115    115      115     115           115
# Beijing   143    143         143    143      143     143           143
# Sydney    188    188         188    188      188     188           188
#
#          Country  Event_gender  Medal
# City
# Athens       192           192    192
# Atlanta      115           115    115
# Beijing      143           143    143
# Sydney       188           188    188

# %%
df[df['Country_Code'] == 'URS'].groupby('City').count()
# Out:
#           Year  Sport  Discipline  Event  Athlete  Gender  Country_Code  \
# City
# Montreal   285    285         285    285      285     285           285
# Moscow     442    442         442    442      442     442           442
# Seoul      294    294         294    294      294     294           294
#
#           Country  Event_gender  Medal
# City
# Montreal      285           285    285
# Moscow        442           442    442
# Seoul         294           294    294

# %%
df.groupby(['Athlete']).count().sort_values('City', ascending= False).head(10)
# Out:
#                      City  Year  Sport  Discipline  Event  Gender  \
# Athlete
# PHELPS, Michael        16    16     16          16     16      16
# FISCHER, Birgit        12    12     12          12     12      12
# NEMOV, Alexei          12    12     12          12     12      12
# TORRES, Dara           12    12     12          12     12      12
# THOMPSON, Jenny        12    12     12          12     12      12
# ANDRIANOV, Nikolay     12    12     12          12     12      12
# COUGHLIN, Natalie      11    11     11          11     11      11
# BIONDI, Matthew        11    11     11          11     11      11
# DITYATIN, Aleksandr    10    10     10          10     10      10
# SCHERBO, Vitaly        10    10     10          10     10      10
#
#                      Country_Code  Country  Event_gender  Medal
# Athlete
# PHELPS, Michael                16       16            16     16
# FISCHER, Birgit                12       12            12     12
# NEMOV, Alexei                  12       12            12     12
# TORRES, Dara                   12       12            12     12
# THOMPSON, Jenny                12       12            12     12
# ANDRIANOV, Nikolay             12       12            12     12
# COUGHLIN, Natalie              11       11            11     11
# BIONDI, Matthew                11       11            11     11
# DITYATIN, Aleksandr            10       10            10     10
# SCHERBO, Vitaly                10       10            10     10

# %%
usa_df = df[df['Country_Code'] == "USA"]
usa_df[usa_df['Sport'] == 'Pentathlon'].groupby(['Athlete', 'Medal','Year']).count().sort_values('Year', ascending = False)
# Out:
#                                        City  Sport  Discipline  Event  Gender  \
# Athlete                   Medal  Year
# WILDER, Deontay           Bronze 2008     1      1           1      1       1
# WARD, Andre               Gold   2004     1      1           1      1       1
# DIRRELL, Andre            Bronze 2004     1      1           1      1       1
# WILLIAMS JR, Ricardo      Silver 2000     1      1           1      1       1
# VINSON, Clarence          Bronze 2000     1      1           1      1       1
# TAYLOR, Jermain           Bronze 2000     1      1           1      1       1
# JUAREZ, Ricardo           Silver 2000     1      1           1      1       1
# JONES, Nate               Bronze 1996     1      1           1      1       1
# WELLS, Rhoshii            Bronze 1996     1      1           1      1       1
# CAUTHEN, Terrance         Bronze 1996     1      1           1      1       1
# TARVER, Antonio           Bronze 1996     1      1           1      1       1
# REID, David               Gold   1996     1      1           1      1       1
# MAYWEATHER, Floyd         Bronze 1996     1      1           1      1       1
# AUSTIN, Timothy           Bronze 1992     1      1           1      1       1
# DE LA HOYA, Oscar         Gold   1992     1      1           1      1       1
# BYRD, Christopher         Silver 1992     1      1           1      1       1
# HILL, Virgil Eugene       Silver 1984             1        1             1
# PAGE, Jeremy Louis        Gold   1984             1        1             1
# BIGGS, Tyrell             Gold   1984             1        1             1
# GONZALEZ, Paul Garza Jr.  Gold   1984             1        1             1
# SPINKS, Michael L.        Gold   1976             1        1             1
# TATE, John                Bronze 1976             1        1             1
# DAVIS, Howard Edward, Jr. Gold   1976             1        1             1
# RANDOLPH, Leonard         Gold   1976             1        1             1
# MOONEY, Charles Michael   Silver 1976             1        1             1
# LEONARD, Ray Charles      Gold   1976             1        1             1
# SPINKS, Leonard, Jr.      Gold   1976             1        1             1

# %%
phelps_df = df[df['Athlete'] == 'PHELPS, Michael']
phelps_df[['Year', 'City', 'Event', 'Medal']]
# Out:
#        Year     City                   Event   Medal
# 11327  2004   Athens          100m butterfly    Gold
# 11330  2004   Athens  200m individual medley    Gold
# 11349  2004   Athens  400m individual medley    Gold
# 11363  2004   Athens  4x200m freestyle relay    Gold
# 11369  2004   Athens  4x100m freestyle relay  Bronze
# 11383  2004   Athens     4x100m medley relay    Gold
# 11413  2004   Athens          200m butterfly    Gold
# 11459  2004   Athens          200m freestyle  Bronze
# 13320  2008  Beijing          200m freestyle    Gold
# 13332  2008  Beijing  400m individual medley    Gold
# 13343  2008  Beijing     4x100m medley relay    Gold
# 13346  2008  Beijing          100m butterfly    Gold
# 13378  2008  Beijing          200m butterfly    Gold
# 13450  2008  Beijing  4x100m freestyle relay    Gold
# 13451  2008  Beijing  4x200m freestyle relay    Gold
# 13480  2008  Beijing  200m individual medley    Gold

# %%
fischer_df = df[df['Athlete'] == 'FISCHER, Birgit']
fischer_df[['Year', 'City', 'Event', 'Medal']]
# Out:
#        Year       City                    Event   Medal
# 1748   1980     Moscow  K-1 500m (kayak single)    Gold
# 4669   1988      Seoul  K-1 500m (kayak single)  Silver
# 4674   1988      Seoul  K-2 500m (kayak double)    Gold
# 4682   1988      Seoul    K-4 500m (kayak four)    Gold
# 6335   1992  Barcelona    K-4 500m (kayak four)  Silver
# 6395   1992  Barcelona  K-1 500m (kayak single)    Gold
# 8100   1996    Atlanta  K-2 500m (kayak double)  Silver
# 8122   1996    Atlanta    K-4 500m (kayak four)    Gold
# 10026  2000     Sydney    K-4 500m (kayak four)    Gold
# 10055  2000     Sydney  K-2 500m (kayak double)    Gold
# 12043  2004     Athens  K-2 500m (kayak double)  Silver
# 12087  2004     Athens    K-4 500m (kayak four)    Gold

# %%
thompson_df = df[df['Athlete'] == 'THOMPSON, Jenny']
thompson_df[['Year', 'City', 'Event', 'Medal']]
# Out:
#        Year       City                   Event   Medal
# 5712   1992  Barcelona  4x100m freestyle relay    Gold
# 5736   1992  Barcelona     4x100m medley relay    Gold
# 5752   1992  Barcelona          100m freestyle  Silver
# 7525   1996    Atlanta     4x100m medley relay    Gold
# 7551   1996    Atlanta  4x200m freestyle relay    Gold
# 7553   1996    Atlanta  4x100m freestyle relay    Gold
# 9297   2000     Sydney     4x100m medley relay    Gold
# 9307   2000     Sydney  4x200m freestyle relay    Gold
# 9383   2000     Sydney  4x100m freestyle relay    Gold
# 9417   2000     Sydney          100m freestyle  Bronze
# 11355  2004     Athens  4x100m freestyle relay  Silver
# 11416  2004     Athens     4x100m medley relay  Silver
